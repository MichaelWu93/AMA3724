# %%
import sympy as sp

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
V1_1 = sp.Matrix([[2],[1],[1]]);V1_1
# Out:
# Matrix([
# [2],
# [1],
# [1]])

# %%
V2_1 = sp.Matrix([[1],[-1],[3]]);V2_1
# Out:
# Matrix([
# [ 1],
# [-1],
# [ 3]])

# %%
V_1 = sp.Matrix([[1],[5],[-7]]);V_1
# Out:
# Matrix([
# [ 1],
# [ 5],
# [-7]])

# %%
span_1 = sp.Matrix([[V1_1,V2_1]]);span_1
# Out:
# Matrix([
# [2,  1],
# [1, -1],
# [1,  3]])

# %%
a,b = sp.symbols('a b')
sol_1 = sp.linsolve((span_1,V_1),a,b);sol_1
#v belongs to span{v_{1},v_{2}}
# Out:
# {(2, -3)}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A_2 = sp.Matrix([[2,1,0],[2,2,0],[0,0,1]]);A_2
# Out:
# Matrix([
# [2, 1, 0],
# [2, 2, 0],
# [0, 0, 1]])

# %%
B_2 = sp.Matrix([[1,0,0],[0,-1,0],[0,0,2]]);B_2
# Out:
# Matrix([
# [1,  0, 0],
# [0, -1, 0],
# [0,  0, 2]])

# %%
# C = (2A-I)B(2A-I)^{-1}
C_2 = (2*A_2-sp.eye(3))*B_2*((2*A_2-sp.eye(3)).inv());C_2
# Out:
# Matrix([
# [17, -12, 0],
# [24, -17, 0],
# [ 0,   0, 2]])

# %%
(2*C_2*A_2 - 2*A_2*B_2) == (C_2 - B_2)
# Out:
# True

# %%
C_2 ** 5
# Out:
# Matrix([
# [17, -12,  0],
# [24, -17,  0],
# [ 0,   0, 32]])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A_4 = sp.Matrix([[0,-3,-2],[-5,9,1]]);A_4
# Out:
# Matrix([
# [ 0, -3, -2],
# [-5,  9,  1]])

# %%
u_4 = sp.Matrix([[5],[3],[-2]]);u_4
# Out:
# Matrix([
# [ 5],
# [ 3],
# [-2]])

# %%
A_4 * u_4 == sp.zeros(3,1)
# u not belongs to the null space of A
# Out:
# False

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A_5 = sp.Matrix([[-3,6,-1,1,-7],[1,-2,2,3,-1],[2,-4,5,8,-4]]);A_5
# Out:
# Matrix([
# [-3,  6, -1, 1, -7],
# [ 1, -2,  2, 3, -1],
# [ 2, -4,  5, 8, -4]])

# %%
x1,x2,x3,x4,x5 = sp.symbols('x1 x2 x3 x4 x5')
sp.linsolve((A_5,sp.zeros(3,1)),x1,x2,x3,x4,x5)
# Out:
# {(2*x2 + x4 - 3*x5, x2, -2*x4 + 2*x5, x4, x5)}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A_6 = sp.Matrix([[1,4,-2,1],[-2,-5,7,3],[3,7,-8,6]]);A_6
# Out:
# Matrix([
# [ 1,  4, -2, 1],
# [-2, -5,  7, 3],
# [ 3,  7, -8, 6]])

# %%
A_6.columnspace()
# k = dim Col(A_{6}) = 3
# Out:
# [Matrix([
#  [ 1],
#  [-2],
#  [ 3]]),
#  Matrix([
#  [ 4],
#  [-5],
#  [ 7]]),
#  Matrix([
#  [-2],
#  [ 7],
#  [-8]])]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
