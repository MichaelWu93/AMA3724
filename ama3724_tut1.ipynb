# %%
import sympy as sp

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A1 = sp.Matrix([[3,17],[19,1]]);A
# Out:
# Matrix([
# [ 3, 17],
# [19,  1]])

# %%
A1.inv()
# Out:
# Matrix([
# [-1/320, 17/320],
# [19/320, -3/320]])

# %%
A1**2
# Out:
# Matrix([
# [332,  68],
# [ 76, 324]])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A2 = sp.Matrix([[10,5,0],[1,19,0]])
B2 = sp.Matrix([[1,1],[1,0]])

# %%
A2.T
# Out:
# Matrix([
# [10,  1],
# [ 5, 19],
# [ 0,  0]])

# %%
B2.T * A2
# Out:
# Matrix([
# [11, 24, 0],
# [10,  5, 0]])

# %%
A2.T * B2
# Out:
# Matrix([
# [11, 10],
# [24,  5],
# [ 0,  0]])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A3 = sp.Matrix([[1,3,5,0],[0,1,0,10],[0,0,1,3],[0,0,0,1]])

# %%
sp.det(A3.T)
# Out:
# 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)
